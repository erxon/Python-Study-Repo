# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Numpy & Matplotlib
x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots() # Create a figure containing a single axes
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]) # Plot some data 
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], "bo") # Blue circle markers
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], "r+") # Red plusses
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], "go--", linewidth=2, markersize=12)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3], color='green', marker='o', linestyle='dashed', linewidth=2, markersize=12)
plt.show()

# %%
fig = plt.figure() # An empty figure with no Axes
fig, ax = plt.subplots() # A figure with a single Axes
fig, axs = plt.subplots(2, 2) # A figure with 2x2 grid of Axes
# A figure with one Axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'], ['left', 'right_bottom']])

# %% [markdown]
# ### Types of inputs to plotting functions

# %%
# Converting numpy matrix
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)

# %%
np.random.seed(19680801) # seed the random number generator
data = {'a': np.arange(50), 'c': np.random.randint(0, 50, 50), 'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry A')
ax.set_ylabel('entry B')
# Out:
# Text(0, 0.5, 'entry B')

# %% [markdown]
# ### The explicit and the implicit interfaces

# %%
# The OO Style

x = np.linspace(0, 2, 100)

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('The OO Style')
ax.legend()

# %%
# The pyplot-style

x = np.linspace(0, 2, 100)

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("The Pyplot Style")
plt.legend()
